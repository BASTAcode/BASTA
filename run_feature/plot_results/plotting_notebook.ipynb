# %%
import numpy as np 
import matplotlib.pyplot as plt 
from plot_results import PostProcessingValidator

# %%
configs = [
    ("no filters", "output_nofilter/M4/"),
    ("age filter only", "output_agefilter/M4/"),
    ("both filters", "output_bothfilters/M4/"),
]

validator = PostProcessingValidator(
    configs, "literatureM_globularClusters.dat"
)

# validator.plot_residuals(separate=True)
validator.plot_residuals(separate=True, chi2_lim=300,xlim=(0, 52), ylim_mass=(0, 2), ylim_age=(0, 20))
